# %% [markdown]
# RESET

# %%
# !rm -r cos711_a3
# !git clone https://github.com/franco-swarts-up/cos711_a3.git && \
cd cos711_a3 && \
git clone https://github.com/ultralytics/yolov5 && \
pip3 install -r yolov5/requirements.txt && \
cp ../drive/MyDrive/cos711/a3/backup.zip . && \
unzip backup.zip && \
rm backup.zip && \
rm -r __MACOSX && \
mkdir data && \
mv test data/ && \
mv train data/ && \
mkdir data/images && \
mkdir data/labels && \
python3 data.py

# %% [markdown]
# REPOSITORY PULL

# %%
# !cd cos711_a3 && \
git pull && \
cd yolov5 && \
git pull && \
pip3 install -r requirements.txt

# %% [markdown]
# TRAIN

# %%
# !cd cos711_a3/yolov5 && \
python3 train.py --img 512 --epochs 10 --data ../cos711_a3.yaml --weights yolov5n.pt --project '../../drive/MyDrive/cos711/a3/train/yolov5n' --name 'run'
# Out:
# ^C

# %% [markdown]
# CLEAN TRAIN RUNS

# %%
# !rm -r drive/MyDrive/cos711/a3/train/yolov5n/run(temp)

# %% [markdown]
# TEST

# %%
# !cd cos711_a3 && \
python3 test.py ../drive/MyDrive/cos711/a3/train/yolov5n/run8/weights/last.pt && \
mv predictions.csv ../drive/MyDrive/cos711/a3/test/yolov5n/run8.csv
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2021-11-14 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1763224 parameters, 0 gradients, 4.2 GFLOPs
# Adding AutoShape...
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# 1
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# 2
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
# ...
